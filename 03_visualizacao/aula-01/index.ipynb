# %% [markdown]
# <a href="https://colab.research.google.com/github/labeduc/ciencia-de-dados/blob/main/03_visualizacao/aula-01/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01 - Teoria de Visualização de Dados

# %% [markdown]
# Olá Cientista de Dados!
#
# Nesta aula, vamos aprender um pouco de teoria sobre Visualização e Ciência de Dados, com o objetivo de compreendermos a importância da Visualização de Dados dentro da Ciência de Dados.

# %% [markdown]
# ### O que é Ciência de Dados

# %% [markdown]
# A ciência de dados é uma disciplina que usa habilidades matemáticas e técnicas avançadas de análise de dados para transformar grandes quantidades de informações em insights úteis. Ela é usada em diversos setores para tomada de decisão informada e resolução de problemas complexos.
#
# Ciência de dados é como ser um detetive super nerd que desvenda mistérios escondidos nos dados. Os cientistas de dados mergulham em montanhas de informações, usando suas habilidades matemáticas e de programação para desvendar padrões ocultos e responder a perguntas importantes. Eles são os mestres em transformar dados bagunçados em conhecimento valioso, ajudando empresas e pesquisadores a tomar decisões informadas. É como ter um superpoder de números e algoritmos, só que sem a capa e a máscara.

# %% [markdown]
# ### O Fluxo de Trabalho de Ciência de Dados

# %% [markdown]
# O **Ciclo de Vida de Ciência de Dados** é a formalização das 6 etapas que os cientistas de dados trabalham a cada projeto para chegar ao final com o resultado solicitado pelo cliente, e podemos ver suas fases na imagem abaixo:
# <center>
#
# ![](ciclo_vida_ds.png)
#
# <small>Fonte: blog.betrybe.com.br</small>
# </center>

# %% [markdown]
# **1 - Entendendo o problema** - aqui é feito o processo de descoberta, onde o problema que o cliente deseja resolvido é devidamente explicado, quebrado em requisitos e os dados disponíveis (ou a falta deles) são disponibilizados.
#
# **2 - Coleta de dados** - nesta fase, os conjuntos de dados iniciais caso existam são validados e se determina que outras fontes podem ser usadas para obter ou enriquecer os dados. Também são escritos os primeiros códigos para realizar a busca e download dos dados.
#
# **3 - Processamento de dados** - nesta fase os dados são analisados e transformados para atender ao propósito de negócio. Também é a fase em que começa o processo de criação de modelos de machine learning.
#
# **4 - Exploração de dados** - esta fase é caracterizada principalmente por visualização de dados sendo utilizada para compreender os dados gerados pelo modelo. São utilizadas técnicas específicas para essa exploração e todas dependem primariamente do bom entendimento na criação de visualizações de dados.
#
# **5 - Comunicação de resultados** - esta fase também reconhecida por fazer uso extensivo de técnicas de visualização de dados aliadas a técnicas de story telling para mostrar ao cliente os resultados obtidos.
#
# **6 - Feedback** - na última fase deste ciclo, se coleta as impressões do cliente e se inicia (caso necessário) uma nova iteração do projeto, para o refinamento da solução apresentada e a possibilidade de trabalhar em novos requisitos.

# %% [markdown]
# ### O que é Visualização de Dados???

# %% [markdown]
# **Visualização de Dados** é a representação gráfica de informações e dados. Ao utilizar elementos visuais como gráficos, mapas e diagramas, ela fornece uma maneira acessível de perceber e compreender tendências, anomalias e padrões que seriam invisíveis em uma tabela de números.
#
# Em outras palavras: é a arte e a ciência de transformar números e tabelas em imagens que o cérebro humano consegue interpretar de forma rápida e intuitiva. Quando bem feita, uma boa visualização comunica em segundos o que levaria parágrafos para explicar em texto.
#
# <center>
#
# ![](definicao_grafico.png)
#
# <small>Fonte: o autor</small>
#
# </center>

# %% [markdown]
# ### Tipos de Visualização

# %% [markdown]
# Existem diversos tipos de visualizações disponíveis. Sua utilização está associada ao tipo de informação e ao objetivo que temos ao mostrar os dados.
#
# <center>
#
# ![](tipos_grafico.png)
#
# <small>Fonte: o autor</small>
#
# </center>
#
# Quanto a objetivos, as visualizações são utilizadas com as seguintes finalidades:
# - **Comparar** valores — [PIB per capita por país (Our World in Data)](https://ourworldindata.org/grapher/gdp-per-capita-worldbank)
# - Evidenciar a **correlação** entre valores (como os dois valores se comportam em conjunto) — [Riqueza vs. Expectativa de vida ao longo do tempo (Gapminder)](https://www.gapminder.org/tools/#$chart-type=bubbles)
# - Como um valor se **distribui** em relação a uma dimensão contínua — [Distribuição de renda entre grupos mais ricos e mais pobres (Our World in Data)](https://ourworldindata.org/grapher/income-share-distribution-wb)
# - Como um valor se distribui especificamente em relação a **posicionamento geográfico** — [Acesso à eletricidade por país (Our World in Data)](https://ourworldindata.org/grapher/share-of-the-population-with-access-to-electricity)
# - Como um valor se distribui entre dimensões não continuas que formam **partes de um todo**; o quanto cada valor representa em relação a esse todo — [Matriz energética brasileira vs. mundial (EPE)](https://www.epe.gov.br/pt/abcdenergia/matriz-energetica-e-eletrica)
# - Como um valor se comporta em relação ao **tempo** — [Expectativa de vida ao longo dos séculos (Our World in Data)](https://ourworldindata.org/grapher/life-expectancy)

# %% [markdown]
# ### Tipos de Visualização X Objetivo de Comunicação

# %% [markdown]
# Abaixo segue um diagrama com uma indicação de quais gráficos podem ser utilizados de acordo com o seu objetivo.

# %% [markdown]
# <center>
#
# ![](visualizacao_x_objetivo.png)
#
# <small>Fonte: o autor</small>
#
# </center>
#
# Este diagrama será o seu **guia de consulta durante todo o curso**. Sempre que precisar criar uma visualização, siga estes passos:
#
# 1. Identifique o **objetivo** da sua visualização — o que você quer comunicar? (comparar, mostrar correlação, distribuição, etc.)
# 2. Localize esse objetivo no diagrama e veja quais **tipos de gráfico** são recomendados para ele.
# 3. Escolha o gráfico mais adequado considerando o seu conjunto de dados e o público que irá receber a informação.
#
# Ao longo das aulas, voltaremos a este diagrama sempre que aprendermos um novo tipo de gráfico, conectando cada técnica ao objetivo de comunicação que ela melhor serve.
#
# > 💡 **Referência rápida:** Caso o diagrama não esteja visível no seu ambiente, aqui está um resumo dos principais objetivos e tipos de gráfico recomendados:
# >
# > | Objetivo | Tipos de gráfico recomendados |
# > |---|---|
# > | **Comparar** valores entre categorias | Barras, Colunas, Radar |
# > | **Distribuição** de valores contínuos | Histograma, Boxplot, Violin |
# > | **Composição** (partes de um todo) | Pizza, Rosca, Barras empilhadas |
# > | **Relação / Correlação** entre variáveis | Dispersão (Scatter), Bolhas |
# > | **Evolução** ao longo do tempo | Linha, Área |
# > | **Distribuição geográfica** | Mapa coroplético, Mapa de pontos |

# %% [markdown]
# ### Como podemos criar Visualizações???

# %% [markdown]
# Assim como existem diversos tipos de visualizações, existem diversas ferramentas. Abaixo, colocamos uma lista de ferramentas para visualização de dados:
#
# | Ferramenta | Descrição |
# |---|---|
# | **Excel** | O clássico. Presente em quase toda empresa, oferece gráficos básicos com poucos cliques. Ótimo ponto de partida, mas limitado para análises complexas. |
# | **Tableau** | Uma das ferramentas mais populares no mercado de BI. Interface de arrastar-e-soltar, muito poderosa para dashboards interativos. |
# | **Power BI** | Solução da Microsoft, amplamente adotada em empresas que já usam o ecossistema Office/Azure. Boa integração com Excel e bancos de dados corporativos. |
# | **Qlik** | Plataforma de analytics com forte capacidade de exploração associativa de dados — permite que o usuário clique em qualquer valor e filtre tudo automaticamente. |
# | **Looker** | Ferramenta do Google (antes chamada Google Data Studio). Popular em times de produto e marketing digital por sua integração com Google Analytics e BigQuery. |
# | **Oracle Analytics** | Solução enterprise da Oracle, geralmente presente em grandes corporações que já usam outros produtos Oracle. |
# | **SAP Business Objects** | Plataforma de BI da SAP, voltada para ambientes corporativos com grandes volumes de dados e integração com sistemas ERP. |
# | **Grafana** | Open source e muito usada por times de tecnologia para monitoramento de sistemas em tempo real — pense em dashboards de servidores, APIs e aplicações. |
# | **Kibana** | Companheira do Elasticsearch: visualiza logs e dados de busca em tempo real. Muito usada em análise de segurança e observabilidade. |
#
# Estas ferramentas se caracterizam por uma interface de usuário totalmente voltada para a criação de visualizações, sem necessidade de programação. Se vocês estivessem em um curso de Análise de Dados, seriam nossa escolha, pois elas focam na modelagem dos dados e criação das visualizações. Mas vocês estão em um curso para iniciarem na carreira de Cientistas de Dados, certo?

# %% [markdown]
# #### Então, como um Cientista de Dados cria visualizações???

# %% [markdown]
# Um Cientista de Dados utiliza a Visualização de Dados de duas formas:
# 1) Como uma ferramenta de exploração dos dados, durante a fase em que estão procurando respostas
# 2) Como uma ferramenta de comunicação, para divulgar resultados
#
# Considerando essas duas necessidades, embora o Cientista de Dados pudesse utilizar ferramentas como as citadas anteriormente, a verdade é que ele precisa de uma ferramenta que consiga combinar o poder da programação, com visualização de dados e também com uma estrutura documental organizada para compartilhamento de informação.
#
# Por isso, iremos utilizar uma tecnologia diferente para aprender visualização de dados: vamos aprender a criar visualizações de forma **programática**, ou seja, vamos criar visualizações utilizando programas escritos em Python.
#
# #### Porquê vamos fazer isso?
#
# Por alguns motivos:
#
# 1) Como cientistas de dados, a maneira mais comum de entregar os resultados do seu trabalho, além de apresentações em powerpoint é através de **notebooks interativos**, como o Google Colab, ou o Jupyter. São ferramentas que ajudam muito no desenvolvimento de um **story telling** orientado a divulgação dos resultados
#
# 2) Atualmente Python é a linguagem a se aprender na carreira de Cientista de Dados. Outras linguagens como R, Julia e até Java também são utilizadas, mas por enquanto, Python é a preferida
#
# 3) As bibliotecas de visualização em Python são muito flexíveis e poderosas, inclusive são utilizadas por algumas das ferramentas citadas acima

# %% [markdown]
# > 📝 **Nota:** Então, agora que toda a teoria necessária está explicada, bora trabalhar??? Na Aula 02, iremos aprender sobre o Google Colab, a ferramenta que escolhemos para conduzir o restante do curso!

# %% [markdown]
# Um abraço, e até a próxima!
#
# Walter.
