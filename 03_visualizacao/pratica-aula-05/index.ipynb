# %% [markdown]
# # Prática 05 - Pandas

# %% [markdown]
# Olá Cientista de Dados!
#
# Chegou a hora de colocar em prática o que aprendemos na Aula 05 sobre a biblioteca **Pandas**. Vamos trabalhar com o mesmo conjunto de dados da aula: o arquivo `pokemons.csv`, que você já conhece bem.
#
# Os exercícios a seguir cobrem os principais tópicos que vimos: carregamento de dados, inspeção, acesso a colunas e linhas, filtragem e agregação. Tente resolver cada exercício antes de consultar a dica!
#
# Vamos lá?

# %% [markdown]
# ## Preparação
#
# Antes de começar, carregue a biblioteca Pandas e o conjunto de dados. Você vai precisar disso para todos os exercícios.

# %%
import pandas as pd

pokemons = pd.read_csv('pokemons.csv')

# %% [markdown]
# ## Exercício 1 - Conhecendo o Dataset
#
# Use as funções de inspeção do Pandas para responder às seguintes perguntas:
#
# 1. Quantas linhas e colunas o dataset possui?
# 2. Qual é a única coluna que possui valores ausentes (nulos)? Quantos valores não-nulos ela tem?
# 3. Qual é o tipo de dado da coluna `Name`?
#
# **Funções úteis:** `info()`, `shape`

# %%
# Escreva seu código aqui

# %% [markdown]
# > 💡 **Dica:** Use `pokemons.shape` para obter as dimensões do DataFrame e `pokemons.info()` para ver os tipos e contagem de valores não-nulos de cada coluna. Colunas com contagem menor que o total de linhas possuem valores ausentes.

# %% [markdown]
# ## Exercício 2 - Estatísticas do Dataset
#
# Utilizando a função `describe()`, responda:
#
# 1. Qual é a média de pontos de vida (`HP`) dos Pokémons?
# 2. Qual é o valor máximo de ataque (`Att`) encontrado no dataset?
# 3. Qual é o desvio padrão do peso (`Weight`)?
#
# **Função útil:** `describe()`

# %%
# Escreva seu código aqui

# %% [markdown]
# > 💡 **Dica:** A função `describe()` retorna um DataFrame com os cálculos estatísticos. Você pode acessar uma coluna específica com `pokemons.describe()['HP']` para ver apenas as estatísticas de pontos de vida, por exemplo.

# %% [markdown]
# ## Exercício 3 - Explorando os Dados
#
# Vamos explorar o conteúdo do dataset de diferentes formas:
#
# 1. Mostre os **5 primeiros** Pokémons do dataset, exibindo apenas as colunas `Number`, `Name`, `Type 1` e `HP`.
# 2. Mostre os **3 últimos** Pokémons do dataset, exibindo as mesmas colunas acima.
# 3. Mostre **4 Pokémons aleatórios**, exibindo as mesmas colunas acima.
#
# **Funções úteis:** `head()`, `tail()`, `sample()`

# %%
# Escreva seu código aqui

# %% [markdown]
# > 💡 **Dica:** Para selecionar apenas algumas colunas, passe uma lista com os nomes para o DataFrame antes de chamar a função: `pokemons[['Number', 'Name', 'Type 1', 'HP']].head(5)`.

# %% [markdown]
# ## Exercício 4 - Filtrando os Dados
#
# Agora vamos praticar os três métodos de filtragem que aprendemos:
#
# 1. Usando **expressão de coluna**: liste os nomes de todos os Pokémons do tipo `Water` (`Type 1`).
# 2. Usando **`query()`**: liste os nomes e o HP de todos os Pokémons do tipo `Fire` que são Lendários (`Legendary == 1.0`).
# 3. Usando **`loc`**: exiba as linhas de índice 100 a 109, mostrando apenas `Name`, `Type 1` e `Type 2`.
#
# **Funções úteis:** expressão de coluna (`[]`), `query()`, `loc`

# %%
# 1. Expressão de coluna - Pokémons do tipo Water

# %%
# 2. query() - Pokémons Fire e Lendários

# %%
# 3. loc - linhas de 100 a 109

# %% [markdown]
# > 💡 **Dica:** Lembre-se que ao usar `query()` com nomes de colunas compostos (com espaço), é preciso envolvê-los em crases: `` `Type 1` ``. Para a expressão de coluna com múltiplos filtros, use `&` no lugar de `and` e envolva cada condição em parênteses.
#
# :::{.callout-warning}
# Evite o uso de `iterrows()` para realizar filtros! Como vimos na aula, além de ser menos legível, é o método com pior performance para trabalhar com DataFrames Pandas.
# :::

# %% [markdown]
# ## Exercício 5 - Agregando os Dados
#
# Por fim, vamos praticar a agregação de dados com `groupby()`:
#
# 1. Conte quantos Pokémons existem para cada valor de `Type 1`. Ordene o resultado do maior para o menor.
# 2. Calcule a **média de HP** por geração (`Generation`). Qual geração tem a maior média de HP?
# 3. Para cada `Type 1`, calcule o **valor máximo de Ataque** (`Att`). Exiba apenas os 5 tipos com maior ataque máximo.
#
# **Funções úteis:** `groupby()`, `count()`, `mean()`, `max()`, `sort_values()`

# %%
# 1. Contagem de Pokémons por Type 1, ordenado do maior para o menor

# %%
# 2. Média de HP por Geração

# %%
# 3. Ataque máximo por Type 1 - top 5

# %% [markdown]
# > 💡 **Dica:** Para ordenar o resultado de um `groupby()`, encadeie a função `sort_values()` ao final. Use o parâmetro `ascending=False` para ordenar do maior para o menor. Para pegar apenas os 5 primeiros, use `head(5)` no final.

# %% [markdown]
# ## Encerrando
#
# Parabéns por chegar até aqui, Cientista de Dados! Nesta prática, exercitamos os principais conceitos da Aula 05:
#
# - Inspecionar o dataset com `info()`, `describe()` e `shape`
# - Explorar o conteúdo com `head()`, `tail()` e `sample()`
# - Selecionar colunas específicas de um DataFrame
# - Filtrar linhas com expressão de coluna, `loc` e `query()`
# - Agregar e sumarizar dados com `groupby()`
#
# Se ainda teve dificuldade em algum exercício, não se preocupe! Volte à Aula 05 e revise o conceito correspondente. A prática leva à perfeição!
#
# Um abraço e até a próxima,
#
# Walter.
