# %% [markdown]
# <a href="https://colab.research.google.com/github/labeduc/ciencia-de-dados/blob/main/03_visualizacao/pratica-aula-08/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prática 08 - Dispersão e Quadrantes

# %% [markdown]
# Olá Cientista de Dados!
#
# Na Aula 08 aprendemos a criar **gráficos de dispersão** com a função `scatterplot()` do Seaborn — um tipo de gráfico que nos permite analisar a relação entre duas variáveis contínuas, identificar outliers e entender a distribuição individualizada dos dados. Também vimos como transformar um gráfico de dispersão em um **Gráfico de Quadrantes**, muito utilizado em análises de posicionamento estratégico.
#
# Nesta prática, vamos exercitar todos esses conceitos com o nosso querido dataset de pokemons. Os exercícios estão em ordem crescente de complexidade — enfrente cada um antes de olhar a dica!
#
# Vamos lá?

# %% [markdown]
# ## Preparação
#
# Importe as bibliotecas e carregue o dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pokemons = pd.read_csv('pokemons.csv')

# %% [markdown]
# ## Exercício 1 - Gráfico de Dispersão Básico
#
# Crie um **gráfico de dispersão** que relacione os **pontos de vida** (`HP`) no eixo X com os **pontos de velocidade** (`Spe`) no eixo Y. Cada ponto do gráfico representará um Pokémon.
#
# O gráfico deve ter:
# - Título: `Relação entre HP e Velocidade`
# - Rótulo do eixo X: `Pontos de Vida (HP)`
# - Rótulo do eixo Y: `Velocidade`
#
# Após gerar o gráfico, observe: existe alguma correlação entre HP e velocidade? Algum Pokémon parece um outlier?
#
# **Função útil:** `scatterplot()`

# %%
# Escreva seu código aqui

# %% [markdown]
# > 💡 **Dica:** A função `scatterplot()` do Seaborn recebe o DataFrame e os parâmetros `x` e `y` com os nomes das colunas. Não esqueça de usar `plt.title()`, `plt.xlabel()`, `plt.ylabel()` e `plt.show()` para finalizar.

# %% [markdown]
# ## Exercício 2 - Colorindo os Pontos com `hue`
#
# O gráfico do Exercício 1 ficou bom, mas ainda não conseguimos diferenciar os Pokémons por categoria. Vamos adicionar cor!
#
# Antes de criar o gráfico, precisamos criar uma nova coluna chamada `Tipo Lendário` que identifique se o Pokémon é lendário ou não. Use a coluna `Legendary` (onde `1.0` = lendário e `0.0` = não lendário) e a função `apply()` para criar essa coluna com os valores `"Lendário"` ou `"Normal"`.
#
# Em seguida, refaça o gráfico do Exercício 1 colorindo os pontos pelo campo `Tipo Lendário` com o parâmetro `hue`.
#
# **Funções úteis:** `apply()`, `scatterplot()` com `hue=`

# %%
# Passo 1: criar a coluna 'Tipo Lendário'


# Passo 2: criar o gráfico com hue

# %% [markdown]
# > 💡 **Dica:**
# > Para criar a nova coluna com `apply()`, use uma função lambda que verifica o valor da coluna `Legendary`:
# > ```python
# > pokemons['Tipo Lendário'] = pokemons['Legendary'].apply(lambda x: 'Lendário' if x == 1.0 else 'Normal')
# > ```
# > Depois, passe `hue='Tipo Lendário'` para o `scatterplot()`.

# %% [markdown]
# ## Exercício 3 - Ajustando a Legenda
#
# Ao usar `hue`, a legenda pode acabar sobrepondo os pontos do gráfico. Vamos resolver isso!
#
# Crie um gráfico de dispersão de **Ataque** (`Att`) no eixo X versus **Defesa** (`Def`) no eixo Y, colorindo os pontos pela **descrição da geração**. Para isso, primeiro crie a coluna `Generation Desc` da mesma forma que foi feito na aula.
#
# Posicione a legenda **fora da área do gráfico**, no canto superior direito.
#
# O gráfico deve ter:
# - Título: `Ataque vs. Defesa por Geração`
# - Rótulo do eixo X: `Pontos de Ataque`
# - Rótulo do eixo Y: `Pontos de Defesa`
#
# **Funções úteis:** `apply()`, `scatterplot()`, `plt.legend(loc=, bbox_to_anchor=)`

# %%
# Passo 1: criar a coluna 'Generation Desc'


# Passo 2: criar o gráfico com hue e legenda posicionada fora do gráfico

# %% [markdown]
# > 💡 **Dica:**
# > Para criar a coluna de descrição da geração: `pokemons['Generation Desc'] = pokemons['Generation'].apply(lambda gen: 'Gen ' + str(int(gen)))`.
# >
# > Para posicionar a legenda fora da área do gráfico, use `plt.legend(loc='upper right', bbox_to_anchor=(1.21, 1.02))`. O parâmetro `bbox_to_anchor` define as coordenadas do canto da legenda em relação ao gráfico — valores maiores que 1 colocam a legenda fora da área de plotagem.

# %% [markdown]
# ## Exercício 4 - Gráfico de Quadrantes
#
# Agora vamos construir um **Gráfico de Quadrantes** — a versão mais sofisticada do gráfico de dispersão! Utilizaremos os atributos **HP** (eixo X) e **Velocidade** (`Spe`) (eixo Y) para classificar os Pokémons em quatro perfis.
#
# O gráfico deve:
# 1. Plotar o `scatterplot()` de `HP` vs `Spe` (sem `hue`)
# 2. Definir os limites dos dois eixos entre `0` e `260`
# 3. Traçar as linhas divisórias dos quadrantes na metade do valor máximo (`130`)
# 4. Adicionar os seguintes rótulos em cada quadrante:
#    - Inferior esquerdo: `"Lentos e Frágeis"`
#    - Inferior direito: `"Resistentes"`
#    - Superior esquerdo: `"Rápidos"`
#    - Superior direito: `"Élite"`
#
# **Funções úteis:** `scatterplot()`, `plt.xlim()`, `plt.ylim()`, `plt.axhline()`, `plt.axvline()`, `plt.text()`

# %%
# Escreva seu código aqui

# %% [markdown]
# > 💡 **Dica:**
# > Siga a sequência da aula:
# > ```python
# > sns.scatterplot(...)       # gráfico base
# > plt.xlim(0, 260)           # limites do eixo X
# > plt.ylim(0, 260)           # limites do eixo Y
# > plt.axhline(y=130, ...)    # linha horizontal no meio
# > plt.axvline(x=130, ...)    # linha vertical no meio
# > plt.text(x=..., y=..., s="Rótulo")  # texto em cada quadrante
# > ```
# > Para os textos, posicione-os próximos aos cantos dos quadrantes. Lembre-se: `x` e `y` nas funções `text()` correspondem ao sistema de coordenadas do gráfico, não à posição em pixels.

# %% [markdown]
# ## Exercício 5 - Quadrante com Filtro
#
# Para finalizar, vamos combinar o que aprendemos de **Pandas** com o Gráfico de Quadrantes!
#
# Reproduza o mesmo Gráfico de Quadrantes do Exercício 4, mas desta vez exibindo **apenas os Pokémons Lendários** (use a coluna `Legendary == 1.0` para filtrar). Além disso, colorize os pontos pela **descrição da geração** (`Generation Desc`) e posicione a legenda fora do gráfico.
#
# Após gerar o gráfico, observe: os Pokémons Lendários se concentram em algum quadrante específico?
#
# **Funções úteis:** filtro Pandas com `query()`, `scatterplot()` com `hue=`, `plt.axhline()`, `plt.axvline()`, `plt.text()`, `plt.legend()`

# %%
# Passo 1: filtrar apenas os Pokémons Lendários


# Passo 2: montar o gráfico de quadrantes com hue e legenda posicionada

# %% [markdown]
# > 💡 **Dica:** Use `query()` para filtrar os lendários antes de plotar: `lendarios = pokemons.query('Legendary == 1.0')`. Depois, passe esse DataFrame filtrado para o `scatterplot()` no lugar de `pokemons`. O restante da construção do quadrante — `axhline()`, `axvline()` e `text()` — funciona exatamente igual ao Exercício 4.

# %% [markdown]
# ## Encerrando
#
# Excelente trabalho, Cientista de Dados! Nesta prática, exercitamos todos os conceitos da Aula 08:
#
# - Criar gráficos de dispersão com `scatterplot()`
# - Colorir os pontos por categoria usando `hue`
# - Criar e transformar colunas no DataFrame com `apply()` e funções lambda
# - Controlar a posição da legenda com `plt.legend()` e `bbox_to_anchor`
# - Construir um Gráfico de Quadrantes completo com linhas divisórias e rótulos
# - Combinar filtros do Pandas com a visualização para análises mais específicas
#
# Os gráficos de dispersão e quadrantes são ferramentas poderosas para comunicar insights de forma visual e intuitiva. Quanto mais você os praticar, mais natural será enxergar padrões nos seus dados!
#
# Um abraço e até a próxima,
#
# Walter.
