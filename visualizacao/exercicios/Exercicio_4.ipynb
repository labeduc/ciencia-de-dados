# %% [markdown]
# <a href="https://colab.research.google.com/github/labeduc/ciencia-de-dados/blob/main/visualizacao/exercicios/Exercicio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregar o dataset
url = "https://media.githubusercontent.com/media/labeduc/datasets/main/nba/2022_2023_NBA_PlayerStats_Regular.csv"
df = pd.read_csv(url, delimiter=";", encoding="latin-1")

df.head(5)
# Out:
#    Rk            Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%
# 0   1  Precious Achiuwa   C   23  TOR  55  12  20.7  3.6   7.3  ...  0.702  \
# 1   2      Steven Adams   C   29  MEM  42  42  27.0  3.7   6.3  ...  0.364
# 2   3       Bam Adebayo   C   25  MIA  75  75  34.6  8.0  14.9  ...  0.806
# 3   4      Ochai Agbaji  SG   22  UTA  59  22  20.5  2.8   6.5  ...  0.812
# 4   5      Santi Aldama  PF   22  MEM  77  20  21.8  3.2   6.8  ...  0.750
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.8  4.1   6.0  0.9  0.6  0.5  1.1  1.9   9.2
# 1  5.1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2  2.5  6.7   9.2  3.2  1.2  0.8  2.5  2.8  20.4
# 3  0.7  1.3   2.1  1.1  0.3  0.3  0.7  1.7   7.9
# 4  1.1  3.7   4.8  1.3  0.6  0.6  0.8  1.9   9.0
#
# [5 rows x 30 columns]

# %%
# 1. Filtragem de Dados
df_filtered = df[df['PTS'] > 10]

df_filtered.head(5)
# Out:
#     Rk                 Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...
# 2    3            Bam Adebayo   C   25  MIA  75  75  34.6   8.0  14.9  ...  \
# 8    7          Grayson Allen  SG   27  MIL  72  70  27.4   3.4   7.7  ...
# 9    8          Jarrett Allen   C   24  CLE  68  68  32.6   5.9   9.2  ...
# 12  11  Giannis Antetokounmpo  PF   28  MIL  63  63  32.1  11.2  20.3  ...
# 14  13           Cole Anthony  PG   22  ORL  60   4  25.9   4.6  10.2  ...
#
#       FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 2   0.806  2.5  6.7   9.2  3.2  1.2  0.8  2.5  2.8  20.4
# 8   0.905  0.8  2.4   3.3  2.3  0.9  0.2  1.0  1.6  10.4
# 9   0.733  3.3  6.5   9.8  1.7  0.8  1.2  1.4  2.3  14.3
# 12  0.645  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1
# 14  0.894  0.8  4.0   4.8  3.9  0.6  0.5  1.5  2.6  13.0
#
# [5 rows x 30 columns]

# %%
# 2. Agregação
team_stats = df.groupby('Tm')[['TRB', 'AST', 'PTS']].mean()

team_stats.head(5)
# Out:
#           TRB       AST       PTS
# Tm
# ATL  3.290000  1.685000  8.385000
# BOS  3.794444  2.016667  8.600000
# BRK  3.488000  2.368000  9.628000
# CHI  3.105556  1.750000  7.888889
# CHO  3.984211  2.415789  9.978947

# %%
# 3. Pivotamento
pivot_table = df.pivot_table(values='PTS', index='Tm', columns='Pos', aggfunc='sum')

pivot_table
# Out:
# Pos     C    PF  PF-SF     PG    SF  SF-SG    SG  SG-PG
# Tm
# ATL  28.0  13.1    NaN   33.6  41.5    NaN  51.5    NaN
# BOS  32.7  46.1    NaN   33.6  30.0    NaN  12.4    NaN
# BRK  18.3  82.6    NaN   56.7  41.6    NaN  41.5    NaN
# CHI  26.1  14.2    NaN   20.7  30.5    NaN  50.5    NaN
# CHO  32.8  19.5    NaN   39.8  65.5    NaN  32.0    NaN
# CLE  17.3  39.7    NaN   30.1  16.8    NaN  51.9    NaN
# DAL  33.6  20.2    NaN   93.5   7.2    NaN  46.0    NaN
# DEN  34.2  34.3    NaN   42.5  18.6    NaN  32.6    NaN
# DET  47.4  33.9    NaN   46.0  25.8    NaN  49.3    NaN
# GSW  13.9  24.8    NaN   57.4  29.8    NaN  45.5    NaN
# HOU  24.0  28.9    NaN   29.7  21.8    NaN  45.8    NaN
# IND  35.5  14.9    NaN   34.6  70.6    NaN  22.0    NaN
# LAC  22.9  26.0    NaN   51.8  23.8    NaN  80.1    NaN
# LAL  44.2  51.2    NaN   54.6  15.0    NaN  46.6    NaN
# MEM  27.2  40.7    NaN   41.7  20.0    NaN  42.9    NaN
# MIA  44.6  22.8    NaN   24.4  50.6    NaN  33.0    NaN
# MIL  27.2  45.2    NaN   45.0  41.4    NaN  25.8    NaN
# MIN  31.4  33.9    NaN   35.6  27.7    NaN  53.2    NaN
# NOP  26.0  32.8    NaN   22.7  58.1    NaN  31.2    NaN
# NYK  15.8  32.5    NaN   48.3  10.0    NaN  48.2    NaN
# OKC  10.2  41.6    NaN   39.1   9.8    NaN  72.1    NaN
# ORL  38.8  38.3    NaN   46.9  27.1    NaN  26.9    NaN
# PHI  46.4  26.4    NaN   34.1  31.5    NaN  50.3    NaN
# PHO  28.9  23.7    NaN   30.5  59.0    NaN  68.9    NaN
# POR  29.3  29.7    NaN   38.9  50.6    NaN  77.8    NaN
# SAC  31.2  23.9    NaN   32.1  17.1    NaN  38.3    NaN
# SAS  44.1  16.9    NaN   25.9  75.9    NaN  48.9    NaN
# TOR  51.8  32.0    NaN   30.9  27.5    NaN  21.9    NaN
# TOT  87.8  69.4   43.2  158.2  96.9    9.8  93.4    7.1
# UTA  29.8  32.3    NaN   23.9  40.1    NaN  73.8    NaN
# WAS  43.4  42.8    NaN   38.5  21.8    NaN  36.7    NaN

# %%
# 4. Cálculos Estatísticos
players_stats = df_filtered[['Age', 'MP']].agg(['mean', 'median', 'std'])

players_stats.head(5)
# Out:
#               Age         MP
# mean    26.407407  29.901852
# median  26.000000  30.300000
# std      4.155214   4.665349

# %%
# 5. Visualizações
# Gráfico de linha - Evolução média de pontos por idade
sns.lineplot(data=df, x='Age', y='PTS')
plt.show()

# %%
# Gráfico de barras - Média de rebotes totais por posição
sns.barplot(data=df, x='Pos', y='TRB', order=['C', 'PF', 'SF', 'SG', 'PG'])
plt.show()

# %%
# Gráfico de área - Distribuição de minutos jogados por time
df.groupby('Tm')['MP'].sum().plot(kind='area')
plt.show()

# %%
# Gráfico de dispersão - Assistências vs. Pontos por jogador
sns.scatterplot(data=df_filtered, x='AST', y='PTS', hue='PTS', size='PTS', sizes=(20, 200))
plt.show()
