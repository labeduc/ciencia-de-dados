# %% [markdown]
# # Visualização e Bancos de dados com Python - Desafio 1

# %% [markdown]
# **Olá!**
#
# Bem-vindos ao nosso Primeiro Desafio de Visualização e Bancos de Dados!
#
# Leia o desafio com atenção, utilize o dicionário de dados e cumpra todas as tarefas!!!

# %% [markdown]
# ## Desafio

# %% [markdown]
# Você acabou de ser contratado como cientista de dados na empresa __LabEducPetz__. O __LabEducPetz__ é focado em realocação de animais para novos lares, ou seja, cuidam do processo de adoção de cachorros.
#
# Com o passar dos anos, a __LabEducPetz__ montou uma base de dados com as características de cada raça, para criar um sistema que auxilie os potenciais tutores a escolher o cachorro que melhor se adequa ao seu estilo de vida.
#
# Como teste para verificar se a base de dados precisa de mais alguma informação para ser adicionada, eles pediram que você monte uma __Prova de Conceito__ com os dados.
#
# __Objetivo:__ Criar uma análise em um notebook do Google Colab que demonstre quais são as raças de cachorro mais indicadas para morar em apartamento.

# %% [markdown]
# __Dicionário de Dados:__
#
# O arquivo que vocês devem carregar se chama _**labeducpetz_desafio_aula_01.csv**_ e os campos são os seguintes:
#
# | **Raça**                       | **Descrição**                 | **Tipo de Dados** |          Valores         |              |              |                  |                    |                 |               |               |
# |--------------------------------|-------------------------------|:-----------------:|:------------------------:|:------------:|:------------:|:----------------:|:------------------:|:---------------:|:-------------:|:-------------:|
# | Raca                           | Nome da raça                  | Texto             |                          |              |              |                  |                    |                 |               |               |
# | Tamanho                        | Tamanho no formato categórico | Texto             | Muito Pequeno            | Pequeno      | Médio        | Grande           | Muito Grande       |                 |               |               |
# | Grupo                          | Categoria de tipo da espécie  | Texto             | Cães de raças misturadas | Cães Terrier | Cães de Caça | Cães de Trabalho | Cães de Companhia  | Cães Esportivos | Cães Pastores | Cães Híbridos |
# | Altura Media cm                |                               | Numérico          |                          |              |              |                  |                    |                 |               |               |
# | Peso Medio kg                  |                               | Numérico          |                          |              |              |                  |                    |                 |               |               |
# | Expectativa Media de Vida anos |                               | Numérico          |                          |              |              |                  |                    |                 |               |               |
# | Bom para Tutores Iniciantes    |                               | Numérico          |         1 - Ruim         |       2      |       3      |         4        |       5 - Bom      |                 |               |               |
# | Nivel de Sensibilidade         |                               | Numérico          |    1 - Pouco Sensível    |       2      |       3      |         4        | 5 - Muito Sensível |                 |               |               |
# | Tolera Ficar Sozinho           |                               | Numérico          |      1 - Não Tolera      |       2      |       3      |         4        |   5 - Tolera Bem   |                 |               |               |
# | Tolera o Frio                  |                               | Numérico          |         1 - Baixo        |       2      |       3      |         4        |      5 - Alto      |                 |               |               |
# | Tolera o Calor                 |                               | Numérico          |         1 - Baixo        |       2      |       3      |         4        |      5 - Alto      |                 |               |               |
# | Gosta de Familia               |                               | Numérico          |       1 - Não Gosta      |       2      |       3      |         4        |      5 - Gosta     |                 |               |               |
# | Gosta de Criança               |                               | Numérico          |       1 - Não Gosta      |       2      |       3      |         4        |      5 - Gosta     |                 |               |               |
# | Gosta de Cachorros             |                               | Numérico          |       1 - Não Gosta      |       2      |       3      |         4        |      5 - Gosta     |                 |               |               |
# | Gosta de Estranhos             |                               | Numérico          |       1 - Não Gosta      |       2      |       3      |         4        |      5 - Gosta     |                 |               |               |
# | Solta Pelo                     |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Baba Muito                     |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Facil de Arrumar               |                               | Numérico          |     1 - Muito Dificil    |       2      |       3      |         4        |   5 - Muito Fácil  |                 |               |               |
# | Saude                          |                               | Numérico          |         1 - Ruim         |       2      |       3      |         4        |       5 - Boa      |                 |               |               |
# | Ganho de Peso                  |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Tamanho                        |                               | Numérico          |     1 - Muito Pequeno    |       2      |       3      |         4        |  5 - Muito Grande  |                 |               |               |
# | Facil de Treinar               |                               | Numérico          |     1 - Muito Dificil    |       2      |       3      |         4        |   5 - Muito Fácil  |                 |               |               |
# | Inteligencia                   |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Barulhento                     |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Cacador                        |                               | Numérico          |    1 - Não caça nunca    |       2      |       3      |         4        |   5 - Caça muito   |                 |               |               |
# | Costuma Latir                  |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Wanderlust Potential           |                               | Numérico          |         1 - Ruim         |       2      |       3      |         4        |       5 - Bom      |                 |               |               |
# | Nivel de Energia               |                               | Numérico          |         1 - Baixo        |       2      |       3      |         4        |      5 - Alto      |                 |               |               |
# | Intensidade                    |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Precisa Exercitar              |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Brincalhao                     |                               | Numérico          |         1 - Pouco        |       2      |       3      |         4        |      5 - Muito     |                 |               |               |
# | Imagem                         | URL da foto da raça           | Texto             |                          |              |              |                  |                    |                 |               |               |

# %% [markdown]
# **Tarefas:**
# - Acessar o nosso repositório de datasets no github (https://github.com/labeduc/datasets)
# - obter o arquivo: labeducpetz/desafio_aula_1.csv
# - carregar os dados no seu programa
# - Mostrar o tipo de dados de cada coluna do dataframe
# - Mostrar as estatísticas das colunas numéricas
# - Mostrar um gráfico de contagem de raças pelo tamanho
# - Mostrar um gráfico de com altura média e peso médio de acordo com o tamanho
# - Utilizando as colunas numéricas, crie uma fórmula para classificar as raças para indicar se elas são apropriadas para a vida em apartamento. Você deve descrever quais colunas utilizou e qual a fórmula utilizada. Como resultado, você deve criar uma nova coluna no dataframe chamada de "Vive em Apartamento".
# - Criar uma nova coluna no dataframe chama "Apartamento Status" que, de acordo com o valor obtido na coluna "Vive em Apartamento", classificará a raça em 2 categorias:
#   - Pode ser criado em Apartamento
#   - Deve ser criado em Casa
# - Mostrar um gráfico de contagem de raças pela nova coluna "Apartamento Status"
# - Selecionar as 10 raças mais aptas a viver em apartamento, mostrando o nome da raça, seu tamanho, altura média, peso médio e o valor da nova coluna "Vive em Apartamento". Esta tarefa deve ser feita plotando os gráficos apropriados para demonstrar essas características.

# %% [markdown]
# ## Critérios de Avaliação

# %% [markdown]
# - Organização - o notebook do Google Colab deve estar bem organizado, demonstrando como cada tarefa foi realizada
# - Criatividade - soluções inovadoras e maneiras diferentes de apresentar o resultado serão consideradas
# - Qualidade do Código - utilizar padrões e convenções para dar nomes as variáveis, comentários explicando pontos não tão nítidos do código são padrão para um bom cientista de dados! A falta de boas práticas de programação serão descontadas
# - A função Run All no notebook deve funcionar sem erros.
